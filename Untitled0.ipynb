# %% [markdown]
# 1. Upload any image on your colab notebook. Write python code to:-
# a. Display your image using matplotlib
# b. Load your uploaded image into a numpy array variable and display the same in
# code.

# %%
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = plt.imread('023.jpg')

# %%
plt.imshow(img)

# %% [markdown]
# 2. Given a 1D NumPy array [1, 2, 3, 4, 5, 6], reshape it into a 2D array with 2 rows and 3
# columns. Print the resulting 2D array.

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4, 5, 6])

# %%
np.reshape(arr1, (2,3))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# 3. Calculate the mean, median, and standard deviation of the following 1D NumPy array:
# [12, 23, 34, 45, 56, 67]

# %%
arr2 = np.array([12, 23, 34, 45, 56, 67])

# %%
arr2.mean()
# Out:
# 39.5

# %%
arr2 = np.sort(arr2)

# %%
arr2
# Out:
# array([12, 23, 34, 45, 56, 67])

# %%
arr2.ndim
# Out:
# 1

# %%
arr2.shape
# Out:
# (6,)

# %%
median = (arr2[3]+arr2[4])/2

# %%
median
# Out:
# 50.5

# %% [markdown]
# 4. Perform matrix multiplication between two 2D NumPy arrays:
# Array A: [[1, 2], [3, 4]]
# Array B: [[5, 6], [7, 8]]
# Print the result of the matrix multiplication A * B.

# %%
A = np.array([1, 2, 3, 4])
np.reshape(A, (2,2))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B = np.array([5, 6, 7, 8])
np.reshape(B, (2,2))
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
A*B
# Out:
# array([25, 36, 49, 64])

# %% [markdown]
# 5. Write a program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.
# Sample Financial data given in a CSV format:
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017
# Plot all the lines showing Open, High, Low, Close wrt Date with different colors in the
# same figure. Also show what each line depicts using a legend.

# %%
import csv

# %%
fields = ['Date', 'Open', 'High', 'Low','Close']

# %%
rows = [['10-03-16', 774.25, 776.065002, 769.5, 772.559998],
['10-04-16', 776.030029, 778.710022, 772.890015, 776.429993],
['10-05-16', 779.309998, 782.070007, 775.650024, 776.469971],
['10-06-16', 779, 780.47998, 775.539978, 776.859985],
['10-07-16', 779.659973, 779.659973, 770.75, 775.080017]]

# %%
filename = 'sample_data.csv'

# %%
with open(filename, 'w') as csvfile:
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %%
csvfile
# Out:
# <_io.TextIOWrapper name='sample_data.csv' mode='w' encoding='UTF-8'>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array(['10-03-16', '10-04-16', '10-05-16', '10-06-16', '10-07-16'])
open = np.array([774.25, 776.030029, 779.309998, 779, 779.659973])
high = np.array([776.065002, 778.710022, 782.070007, 780.47998, 779.659973])

plt.plot(xpoints, open, color = 'blue')
plt.plot(xpoints, high, color = 'red')
