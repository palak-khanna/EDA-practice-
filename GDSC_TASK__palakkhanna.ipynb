# %% [markdown]
# <a href="https://colab.research.google.com/github/palak-khanna/EDA/blob/EDA-AIML/GDSC_TASK__palakkhanna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. a. Create and display a DataFrame from the above dictionary data which has
# index labels.
#
# Given Dictionary:-
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael',
# 'Matthew', 'Laura', 'Kevin', 'Jonas'], 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5,
# np.nan, 8, 19], 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1], 'qualify': ['yes', 'no', 'yes',
# 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import numpy as np
import pandas as pd

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
             }

df = pd.DataFrame(exam_data, index =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# b. Select and display the rows where the number of attempts in the
# examination is greater than 2.

# %%
df[df['attempts']>2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
df.where(df['attempts']>2)
# Out:
#       name  score  attempts qualify
# a      NaN    NaN       NaN     NaN
# b     Dima    9.0       3.0      no
# c      NaN    NaN       NaN     NaN
# d    James    NaN       3.0      no
# e      NaN    NaN       NaN     NaN
# f  Michael   20.0       3.0     yes
# g      NaN    NaN       NaN     NaN
# h      NaN    NaN       NaN     NaN
# i      NaN    NaN       NaN     NaN
# j      NaN    NaN       NaN     NaN

# %% [markdown]
# c. Count the number of rows and columns of the DataFrame.

# %%
df.shape
# Out:
# (10, 4)

# %%
row = df.shape[0]
row
# Out:
# 10

# %%
col = df.shape[1]
col
# Out:
# 4

# %% [markdown]
# d. Select the rows where the score is missing, i.e. is NaN.

# %%
df.isna()
# Out:
#     name  score  attempts  qualify
# a  False  False     False    False
# b  False  False     False    False
# c  False  False     False    False
# d  False   True     False    False
# e  False  False     False    False
# f  False  False     False    False
# g  False  False     False    False
# h  False   True     False    False
# i  False  False     False    False
# j  False  False     False    False

# %%
df[df['score'].isnull() == True]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# e. Change the score in row 'd' to 11.5

# %%
df.loc['d'].fillna(11.5)
# Out:
# name        James
# score        11.5
# attempts        3
# qualify        no
# Name: d, dtype: object

# %%
df.loc['d']
# Out:
# name        James
# score         NaN
# attempts        3
# qualify        no
# Name: d, dtype: object

# %% [markdown]
# f. Calculate the sum of the examination attempts by the students.

# %%
df['attempts'].sum()
# Out:
# 19

# %% [markdown]
# g. Append a new row 'k' to DataFrame with given values for each column.
# Values for each column will be:
# name : ‘Suresh’, score: 15.5, attempts: 1, qualify: ‘yes’; label: ‘k’

# %%
df.loc['k'] = ['suresh', 15.5, 1, 'yes']

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     suresh   15.5         1     yes

# %% [markdown]
# Sort the data frame first by 'name' in descending order, then by 'score' in
# ascending order.

# %%
df.sort_values('name', ascending=False)
# Out:
#         name  score  attempts qualify
# k     suresh   15.5         1     yes
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes

# %%
df.sort_values('score')
# Out:
#         name  score  attempts qualify
# i      Kevin    8.0         2      no
# b       Dima    9.0         3      no
# e      Emily    9.0         2      no
# a  Anastasia   12.5         1     yes
# g    Matthew   14.5         1     yes
# k     suresh   15.5         1     yes
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# f    Michael   20.0         3     yes
# d      James    NaN         3      no
# h      Laura    NaN         1      no

# %% [markdown]
# 2. Dataset: Use ‘Automobile_data.csv’
# a. Load and Print first ten rows of the dataset.
# b. Drop a column.
# c. Print the last five rows.
# d. Print All Toyota Cars details.
# e. Count total cars per company
# f. Find each company’s Highest priced car.
# g. Get average mileage of all the cars.
# h. Sort all cars by Price column.

# %%
df1 = pd.read_csv('Automobile_data.csv')

# %%
df1
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df1.loc[0:9:1]
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          bmw        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan       101.2   176.8         ohc
# 9     11          bmw        sedan       101.2   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# ...

# %%
df1.loc[51:60:1]
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 51     69      toyota      wagon        95.7   169.7         ohc
# 52     70      toyota      wagon        95.7   169.7         ohc
# 53     71      toyota      wagon        95.7   169.7         ohc
# 54     79      toyota      wagon       104.5   187.8        dohc
# 55     80  volkswagen      sedan        97.3   171.7         ohc
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# 53             four          62               27   8778.0
# ...

# %% [markdown]
# b. Drop a column.

# %%
df1.drop('body-style', axis=1)
# Out:
#     index      company  wheel-base  length engine-type num-of-cylinders  \
# 0       0  alfa-romero        88.6   168.8        dohc             four
# 1       1  alfa-romero        88.6   168.8        dohc             four
# 2       2  alfa-romero        94.5   171.2        ohcv              six
# 3       3         audi        99.8   176.6         ohc             four
# 4       4         audi        99.4   176.6         ohc             five
# ..    ...          ...         ...     ...         ...              ...
# 56     81   volkswagen        97.3   171.7         ohc             four
# 57     82   volkswagen        97.3   171.7         ohc             four
# 58     86   volkswagen        97.3   171.7         ohc             four
# 59     87        volvo       104.3   188.8         ohc             four
# 60     88        volvo       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111               21  13495.0
# ...

# %% [markdown]
# Print the last five rows.

# %%
df1.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# Print All Toyota Cars details.

# %%
df1.loc[df1['company']== 'toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# Count total cars per company

# %%
df1.groupby('company').count()
# Out:
#                index  body-style  wheel-base  length  engine-type  \
# company
# alfa-romero        3           3           3       3            3
# audi               4           4           4       4            4
# bmw                6           6           6       6            6
# chevrolet          3           3           3       3            3
# dodge              2           2           2       2            2
# honda              3           3           3       3            3
# isuzu              3           3           3       3            3
# jaguar             3           3           3       3            3
# mazda              5           5           5       5            5
# mercedes-benz      4           4           4       4            4
# mitsubishi         4           4           4       4            4
# nissan             5           5           5       5            5
# porsche            3           3           3       3            3
# ...

# %% [markdown]
# Find each company’s Highest priced car.

# %%
 df1.groupby('company')['price'].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %% [markdown]
# Get average mileage of all the cars.

# %%
df1['average-mileage']
# Out:
# 0     21
# 1     21
# 2     19
# 3     24
# 4     18
#       ..
# 56    27
# 57    37
# 58    26
# 59    23
# 60    23
# Name: average-mileage, Length: 61, dtype: int64

# %% [markdown]
# Sort all cars by Price column.

# %%
df1.sort_values('price')
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 13     16      chevrolet  hatchback        88.4   141.1           l
# 27     36          mazda  hatchback        93.1   159.1         ohc
# 48     66         toyota  hatchback        95.7   158.7         ohc
# 36     49     mitsubishi  hatchback        93.7   157.3         ohc
# 28     37          mazda  hatchback        93.1   159.1         ohc
# ..    ...            ...        ...         ...     ...         ...
# 11     14            bmw      sedan       103.5   193.8         ohc
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
# 22     31          isuzu      sedan        94.5   155.9         ohc
# 23     32          isuzu      sedan        94.5   155.9         ohc
# 47     63        porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# ...
