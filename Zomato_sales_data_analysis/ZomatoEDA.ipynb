# %% [markdown]
# <a href="https://colab.research.google.com/github/palak-khanna/EDA/blob/EDA-AIML/ZomatoEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# file importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualising data
# %matplotlib inline
import seaborn as sns

# %%
# Read the file from specified path
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# reading data
data = pd.read_csv("/content/drive/MyDrive/zomato_dataset.csv")
# to avoid encoding error, use 'unicode_escape'

# %%
data.shape
# Out:
# (1965, 15)

# %%
data.head(10)
# Out:
#                  Restaurant_Name  \
# 0                       Rustom's
# 1                      Cafe Lota
# 2         Dum-Pukht - ITC Maurya
# 3                    Burma Burma
# 4                  The Big Chill
# 5                  Carnatic Cafe
# 6  Cocktails & Dreams, Speakeasy
# 7              Natural Ice Cream
# 8   Kuremal Mohan Lal Kulfi Wale
# 9                     Juggernaut
#
#                                             Category  Pricing_for_2  \
# 0  Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1        Cafe, South Indian, North Indian, Beverages           1200
# 2                    Mughlai, North Indian, Desserts           5000
# 3        Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                     Continental, American, Italian           1500
# 5                                       South Indian            600
# 6                       Nepalese, Tibetan, Beverages           2500
# ...

# %%
# DATA CLEANING AND FILLING EMPLTY SPACES
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1965 entries, 0 to 1964
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Restaurant_Name        1965 non-null   object
#  1   Category               1965 non-null   object
#  2   Pricing_for_2          1965 non-null   int64
#  3   Locality               1965 non-null   object
#  4   Dining_Rating          1965 non-null   float64
#  5   Dining_Review_Count    1965 non-null   int64
#  6   Delivery_Rating        1563 non-null   float64
#  7   Delivery_Rating_Count  1965 non-null   int64
#  8   Website                1965 non-null   object
#  9   Address                1965 non-null   object
#  10  Phone_No               1965 non-null   object
#  11  Latitude               1965 non-null   float64
#  12  Longitude              1965 non-null   float64
#  13  Known_For2             1560 non-null   object
# ...

# %%
pd.isnull(data)
# Out:
#       Restaurant_Name  Category  Pricing_for_2  Locality  Dining_Rating  \
# 0               False     False          False     False          False
# 1               False     False          False     False          False
# 2               False     False          False     False          False
# 3               False     False          False     False          False
# 4               False     False          False     False          False
# ...               ...       ...            ...       ...            ...
# 1960            False     False          False     False          False
# 1961            False     False          False     False          False
# 1962            False     False          False     False          False
# 1963            False     False          False     False          False
# 1964            False     False          False     False          False
#
#       Dining_Review_Count  Delivery_Rating  Delivery_Rating_Count  Website  \
# ...

# %%
pd.isnull(data).sum()
# check for null values
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating          402
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
x = data['Delivery_Rating'].mean()

# %%
x
# Out:
# 3.964299424184261

# %%
data['Delivery_Rating'].fillna(x, inplace = True)

# %%
data['Known_For2'].value_counts()
# Out:
# Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more    15
# Finger Food, Continental, Mediterranean, Italian, Asian                                                      9
# Continental, Italian, Fast Food, North Indian, Beverages, Coffee                                             7
# Chinese, Asian, Continental, North Indian, Beverages                                                         2
# Butterscotch Pastry, Truffle Pastry, Chocolate Truffle Cake, Pastries, Waffle, Cakes                         2
#                                                                                                             ..
# Passion Fruit Ice Tea, Cardamom Tea, Bun Tikki, Earl Grey Tea, Rose Tea, Smoked Chicken Pasta                1
# Chicken Crostini, Blackberry Mojito, Butter Maggi, Peri Fries, Masala Tea, Hot Coffee                        1
# ...

# %%
data['Known_For2'].fillna('Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more', inplace=True)

# %%
data['Known_For22'].value_counts()
# Out:
# Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality                     2
# Artistic Decor, The Service, Natural Ambience, Fusion Menu, Serene Ambience, Fusion Food                               1
# Excellent Place, Great Value, Nice Service, Recommended Place, Good Quality Food, Amazing Taste                        1
# Amazing Food and Experience, Delivery Instructions, Genuine Price, Faster Delivery, Worth the Price, Food Packaging    1
# Budget Food, Good for Large Groups, Packed on Weekends, Portions, Good Taste, Main Course                              1
#                                                                                                                       ..
# Classy Decor, Wonderful Service, Chinese, Server, Excellent Food, Hospitality                                          1
# Pocket Friendly, Nice Crowd, Great Ambiance, Polite Staff, Prompt Service, Worth the Money                             1
# ...

# %%
data['Known_For22'].fillna('Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality', inplace = True)

# %%
pd.isnull(data).sum()
# Out:
# Restaurant_Name          0
# Category                 0
# Pricing_for_2            0
# Locality                 0
# Dining_Rating            0
# Dining_Review_Count      0
# Delivery_Rating          0
# Delivery_Rating_Count    0
# Website                  0
# Address                  0
# Phone_No                 0
# Latitude                 0
# Longitude                0
# Known_For2               0
# Known_For22              0
# dtype: int64

# %%
# DATA OF RESTRAUNT WITH DELIVERY RATING>=4.5

# %%
# there was no restrount with more that 4.5 rating, so cofirming for rating more than or equal to 4.5
data[data['Delivery_Rating']>=4.5]
# Out:
#                            Restaurant_Name  \
# 7                        Natural Ice Cream
# 152   The Haven International Coffee House
# 249                          Sibang Bakery
# 269                              BreadTalk
# 829                              Krua Thai
# 1342               KAP's Restro Bar & Cafe
# 1445                              Choko La
# 1505                        Twist of Italy
#
#                                                Category  Pricing_for_2  \
# 7                                   Ice Cream, Desserts            400
# 152   Cafe, Fast Food, Continental, Beverages, Desse...            500
# 249                                 Beverages, Desserts            500
# 269                         Bakery, Fast Food, Desserts            450
# 829                                         Asian, Thai           1500
# 1342  North Indian, Chinese, Mughlai, Fast Food, Fin...           1200
# 1445                                   Bakery, Desserts            400
# ...

# %%
# MOST LIKED FOOD COUNT

# %%
data['Category'].value_counts()
# therefore as seen the count of 'North Indian' food category is max
# Out:
# North Indian                                                      88
# North Indian, Chinese                                             39
# North Indian, Mughlai                                             37
# Pizza, Fast Food                                                  19
# North Indian, Chinese, Mughlai                                    17
#                                                                   ..
# North Indian, Kebab, Mughlai, Biryani, Beverages                   1
# North Indian, Continental, Italian, Chinese                        1
# North Indian, Continental, Asian, Chinese                          1
# Afghan, Iranian, Awadhi, Beverages                                 1
# Cafe, North Indian, Chinese, Kashmiri, Rolls, Pizza, Beverages     1
# Name: Category, Length: 1355, dtype: int64

# %%
# COUNT OF PEOLPE PREFERRING DELIVERY THAN DINING

# %%
data['Dining_Review_Count'].sum()
# Out:
# 1418640

# %%
data['Delivery_Rating_Count'].sum()
# Out:
# 5953067

# %%
# as notice deliveries made are more than number of dinings
# hence number of people preffering deliveries than dinings
data['Delivery_Rating_Count'].sum() - data['Dining_Review_Count'].sum()
# Out:
# 4534427

# %%
data_frame = data[data['Delivery_Rating']>=4.0]

# %%
# BAR GRAPH

# %%
plt.bar(data_frame['Restaurant_Name'], data_frame['Delivery_Rating'], color= 'blue')
plt.xlabel('Restaurant', fontsize=4)
plt.ylabel('Delivery Rating', fontsize=4)
# Out:
# Text(0, 0.5, 'Delivery Rating')
